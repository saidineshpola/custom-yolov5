# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov5" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov5/v70/splash.png"></a>
#
#
# <br>
#   <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# <br>
#
# This <a href="https://github.com/ultralytics/yolov5">YOLOv5</a> 🚀 notebook by <a href="https://ultralytics.com">Ultralytics</a> presents simple train, validate and predict examples to help start your AI adventure.<br>We hope that the resources in this notebook will help you get the most out of YOLOv5. Please browse the YOLOv5 <a href="https://docs.ultralytics.com/yolov5">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/yolov5">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
# </div>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Load your dataset from the CSV file
data = pd.read_csv('datasets/phase2_train_v0/phase2_train_v0.csv')

# Split the data into training and validation sets while maintaining class distribution
train_data, valid_data = train_test_split(data, test_size=0.05, stratify=data['class_label'])

# Save the validation data to a new CSV file
valid_data.to_csv('datasets/phase2_train_v0/validation_dataset.csv', index=False)

# %%
import os
import shutil
import pandas as pd

# Load the validation dataset CSV file
validation_data = pd.read_csv('datasets/phase2_train_v0/validation_dataset.csv')

# Set the source directories for images and labels in the train directory
train_images_dir = 'datasets/train/images'
train_labels_dir = 'datasets/train/labels'

# Set the destination directories for images and labels in the val directory
val_images_dir = 'datasets/val/images'
val_labels_dir = 'datasets/val/labels'

# Create the destination directories if they don't exist
os.makedirs(val_images_dir, exist_ok=True)
os.makedirs(val_labels_dir, exist_ok=True)

# Iterate through each row in the validation dataset
for index, row in validation_data.iterrows():
    img_filename = row['img_fName']
    label_filename = os.path.splitext(img_filename)[0] + '.txt'

    # Copy the image file from train/images to val/images
    src_img_path = os.path.join(train_images_dir, img_filename)
    dst_img_path = os.path.join(val_images_dir, img_filename)
    shutil.copy(src_img_path, dst_img_path)

    # Copy the label file from train/labels to val/labels
    src_label_path = os.path.join(train_labels_dir, label_filename)
    dst_label_path = os.path.join(val_labels_dir, label_filename)
    shutil.copy(src_label_path, dst_label_path)

# %% [markdown]
# ## delete val data fromTrain

# %%
import os

# Define the directories
source_directory = 'datasets/train/images/'  # Replace with your source directory
target_directory = 'datasets/val/images/'  # Replace with your target directory

# Get a list of files in both directories
source_files = os.listdir(source_directory)
target_files = os.listdir(target_directory)

# Iterate through the source files
for file in source_files:
    source_file_path = os.path.join(source_directory, file)
    
    # Check if the file exists in the target directory
    if file in target_files:
        target_file_path = os.path.join(target_directory, file)
        
        # Remove the file from the source directory
        os.remove(source_file_path)
        print(f"Removed {file} from the source directory.")
# Out:
# Removed train_01667.jpeg from the source directory.
# Removed train_03489.jpeg from the source directory.
# Removed train_03324.jpeg from the source directory.
# Removed train_00703.jpeg from the source directory.
# Removed train_06827.jpeg from the source directory.
# Removed train_09224.jpeg from the source directory.
# Removed train_04565.jpeg from the source directory.
# Removed train_09882.jpeg from the source directory.
# Removed train_01585.jpeg from the source directory.
# Removed train_08129.jpeg from the source directory.
# Removed train_06636.jpeg from the source directory.
# Removed train_04644.jpeg from the source directory.
# Removed train_08921.jpeg from the source directory.
# Removed train_06445.jpeg from the source directory.
# Removed train_06572.jpeg from the source directory.
# Removed train_09034.jpeg from the source directory.
# Removed train_04036.jpeg from the source directory.
# Removed train_08926.jpeg from the source directory.
# Removed train_08514.jpeg from the source directory.
# Removed train_05039.jpeg from the source directory.
# Removed train_05734.jpeg from the source directory.
# Removed train_09732.jpeg from the source directory.
# Removed train_01459.jpeg from the source directory.
# Removed train_03401.jpeg from the source directory.
# Removed train_01904.jpeg from the source directory.
# Removed train_00906.jpeg from the source directory.
# Removed train_08955.jpeg from the source directory.
# Removed train_03860.jpeg from the source directory.
# Removed train_09864.jpeg from the source directory.
# Removed train_01964.jpeg from the source directory.
# Removed train_00575.jpeg from the source directory.
# Removed train_02218.jpeg from the source directory.
# Removed train_06441.jpeg from the source directory.
# Removed train_02639.jpeg from the source directory.
# Removed train_00557.jpeg from the source directory.
# Removed train_07649.jpeg from the source directory.
# Removed train_08923.jpeg from the source directory.
# Removed train_03344.jpeg from the source directory.
# Removed train_06848.jpeg from the source directory.
# Removed train_02802.jpeg from the source directory.
# Removed train_01556.jpeg from the source directory.
# Removed train_10229.jpeg from the source directory.
# Removed train_01593.jpeg from the source directory.
# Removed train_10121.jpeg from the source directory.
# Removed train_00947.jpeg from the source directory.
# Removed train_00081.jpeg from the source directory.
# Removed train_06088.jpeg from the source directory.
# Removed train_02140.jpeg from the source directory.
# Removed train_08195.jpeg from the source directory.
# Removed train_04683.jpeg from the source directory.
# Removed train_05910.jpeg from the source directory.
# Removed train_08597.jpeg from the source directory.
# Removed train_04601.jpeg from the source directory.
# Removed train_08609.jpeg from the source directory.
# Removed train_02642.jpeg from the source directory.
# Removed train_00920.jpeg from the source directory.
# Removed train_03294.jpeg from the source directory.
# Removed train_09120.jpeg from the source directory.
# Removed train_07120.jpeg from the source directory.
# Removed train_03664.jpeg from the source directory.
# Removed train_03641.jpeg from the source directory.
# Removed train_05778.jpeg from the source directory.
# Removed train_06339.jpeg from the source directory.
# Removed train_03156.jpeg from the source directory.
# Removed train_08553.jpeg from the source directory.
# Removed train_02217.jpeg from the source directory.
# Removed train_01234.jpeg from the source directory.
# Removed train_05959.jpeg from the source directory.
# Removed train_09266.jpeg from the source directory.
# Removed train_10163.jpeg from the source directory.
# Removed train_03738.jpeg from the source directory.
# Removed train_04703.jpeg from the source directory.
# Removed train_04530.jpeg from the source directory.
# Removed train_04916.jpeg from the source directory.
# Removed train_05281.jpeg from the source directory.
# Removed train_08726.jpeg from the source directory.
# Removed train_10152.jpeg from the source directory.
# Removed train_03452.jpeg from the source directory.
# Removed train_01625.jpeg from the source directory.
# Removed train_03546.jpeg from the source directory.
# Removed train_08305.jpeg from the source directory.
# Removed train_07083.jpeg from the source directory.
# Removed train_03125.jpeg from the source directory.
# Removed train_05064.jpeg from the source directory.
# Removed train_00618.jpeg from the source directory.
# Removed train_08654.jpeg from the source directory.
# Removed train_00442.jpeg from the source directory.
# Removed train_02998.jpeg from the source directory.
# Removed train_10254.jpeg from the source directory.
# Removed train_07586.jpeg from the source directory.
# Removed train_06639.jpeg from the source directory.
# Removed train_08038.jpeg from the source directory.
# Removed train_02385.jpeg from the source directory.
# Removed train_03254.jpeg from the source directory.
# Removed train_00293.jpeg from the source directory.
# Removed train_02160.jpeg from the source directory.
# Removed train_02675.jpeg from the source directory.
# Removed train_00109.jpeg from the source directory.
# Removed train_02766.jpeg from the source directory.
# Removed train_06003.jpeg from the source directory.
# Removed train_01523.jpeg from the source directory.
# Removed train_07190.jpeg from the source directory.
# Removed train_04723.jpeg from the source directory.
# Removed train_00652.jpeg from the source directory.
# Removed train_02674.jpeg from the source directory.
# Removed train_09159.jpeg from the source directory.
# Removed train_04082.jpeg from the source directory.
# Removed train_04963.jpeg from the source directory.
# Removed train_09659.jpeg from the source directory.
# Removed train_10251.jpeg from the source directory.
# Removed train_05291.jpeg from the source directory.
# Removed train_03346.jpeg from the source directory.
# Removed train_05646.jpeg from the source directory.
# Removed train_06737.jpeg from the source directory.
# Removed train_02108.jpeg from the source directory.
# Removed train_05377.jpeg from the source directory.
# Removed train_02189.jpeg from the source directory.
# Removed train_08561.jpeg from the source directory.
# Removed train_00093.jpeg from the source directory.
# Removed train_05403.jpeg from the source directory.
# Removed train_09263.jpeg from the source directory.
# Removed train_05537.jpeg from the source directory.
# Removed train_06557.jpeg from the source directory.
# Removed train_01162.jpeg from the source directory.
# Removed train_05982.jpeg from the source directory.
# Removed train_06596.jpeg from the source directory.
# Removed train_03208.jpeg from the source directory.
# Removed train_03426.jpeg from the source directory.
# Removed train_07350.jpeg from the source directory.
# Removed train_03913.jpeg from the source directory.
# Removed train_07817.jpeg from the source directory.
# Removed train_04308.jpeg from the source directory.
# Removed train_06343.jpeg from the source directory.
# Removed train_06203.jpeg from the source directory.
# Removed train_05308.jpeg from the source directory.
# Removed train_05774.jpeg from the source directory.
# Removed train_04867.jpeg from the source directory.
# Removed train_07968.jpeg from the source directory.
# Removed train_09779.jpeg from the source directory.
# Removed train_08063.jpeg from the source directory.
# Removed train_08113.jpeg from the source directory.
# Removed train_01806.jpeg from the source directory.
# Removed train_02636.jpeg from the source directory.
# Removed train_02157.jpeg from the source directory.
# Removed train_01782.jpeg from the source directory.
# Removed train_04981.jpeg from the source directory.
# Removed train_00828.jpeg from the source directory.
# Removed train_02741.jpeg from the source directory.
# Removed train_03790.jpeg from the source directory.
# Removed train_01289.jpeg from the source directory.
# Removed train_05251.jpeg from the source directory.
# Removed train_04862.jpeg from the source directory.
# Removed train_06096.jpeg from the source directory.
# Removed train_08432.jpeg from the source directory.
# Removed train_03234.jpeg from the source directory.
# Removed train_02039.jpeg from the source directory.
# Removed train_07178.jpeg from the source directory.
# Removed train_00871.jpeg from the source directory.
# Removed train_05422.jpeg from the source directory.
# Removed train_08933.jpeg from the source directory.
# Removed train_10119.jpeg from the source directory.
# Removed train_01673.jpeg from the source directory.
# Removed train_05206.jpeg from the source directory.
# Removed train_06668.jpeg from the source directory.
# Removed train_07516.jpeg from the source directory.
# Removed train_02340.jpeg from the source directory.
# Removed train_09006.jpeg from the source directory.
# Removed train_00254.jpeg from the source directory.
# Removed train_09415.jpeg from the source directory.
# Removed train_07540.jpeg from the source directory.
# Removed train_08251.jpeg from the source directory.
# Removed train_01742.jpeg from the source directory.
# Removed train_05590.jpeg from the source directory.
# Removed train_02755.jpeg from the source directory.
# Removed train_02850.jpeg from the source directory.
# Removed train_08297.jpeg from the source directory.
# Removed train_03202.jpeg from the source directory.
# Removed train_07289.jpeg from the source directory.
# Removed train_09610.jpeg from the source directory.
# Removed train_04495.jpeg from the source directory.
# Removed train_06309.jpeg from the source directory.
# Removed train_08344.jpeg from the source directory.
# Removed train_05567.jpeg from the source directory.
# Removed train_01766.jpeg from the source directory.
# Removed train_04170.jpeg from the source directory.
# Removed train_02672.jpeg from the source directory.
# Removed train_01429.jpeg from the source directory.
# Removed train_05083.jpeg from the source directory.
# Removed train_05160.jpeg from the source directory.
# Removed train_05882.jpeg from the source directory.
# Removed train_09987.jpeg from the source directory.
# Removed train_05844.jpeg from the source directory.
# Removed train_04783.jpeg from the source directory.
# Removed train_02794.jpeg from the source directory.
# Removed train_03163.jpeg from the source directory.
# Removed train_04950.jpeg from the source directory.
# Removed train_01798.jpeg from the source directory.
# Removed train_00590.jpeg from the source directory.
# Removed train_04357.jpeg from the source directory.
# Removed train_03604.jpeg from the source directory.
# Removed train_01931.jpeg from the source directory.
# Removed train_06212.jpeg from the source directory.
# Removed train_01663.jpeg from the source directory.
# Removed train_05193.jpeg from the source directory.
# Removed train_08143.jpeg from the source directory.
# Removed train_05195.jpeg from the source directory.
# Removed train_01344.jpeg from the source directory.
# Removed train_09262.jpeg from the source directory.
# Removed train_07678.jpeg from the source directory.
# Removed train_07137.jpeg from the source directory.
# Removed train_04826.jpeg from the source directory.
# Removed train_08963.jpeg from the source directory.
# Removed train_06963.jpeg from the source directory.
# Removed train_03411.jpeg from the source directory.
# Removed train_01744.jpeg from the source directory.
# Removed train_02607.jpeg from the source directory.
# Removed train_04026.jpeg from the source directory.
# Removed train_00207.jpeg from the source directory.
# Removed train_09832.jpeg from the source directory.
# Removed train_04347.jpeg from the source directory.
# Removed train_05979.jpeg from the source directory.
# Removed train_04369.jpeg from the source directory.
# Removed train_08641.jpeg from the source directory.
# Removed train_10008.jpeg from the source directory.
# Removed train_09838.jpeg from the source directory.
# Removed train_02253.jpeg from the source directory.
# Removed train_00896.jpeg from the source directory.
# Removed train_00320.jpeg from the source directory.
# Removed train_04390.jpeg from the source directory.
# Removed train_07943.jpeg from the source directory.
# Removed train_07702.jpeg from the source directory.
# Removed train_02432.jpeg from the source directory.
# Removed train_02270.jpeg from the source directory.
# Removed train_06017.jpeg from the source directory.
# Removed train_08391.jpeg from the source directory.
# Removed train_05827.jpeg from the source directory.
# Removed train_00037.jpeg from the source directory.
# Removed train_08227.jpeg from the source directory.
# Removed train_05094.jpeg from the source directory.
# Removed train_06109.jpeg from the source directory.
# Removed train_06819.jpeg from the source directory.
# Removed train_05378.jpeg from the source directory.
# Removed train_03459.jpeg from the source directory.
# Removed train_09509.jpeg from the source directory.
# Removed train_01440.jpeg from the source directory.
# Removed train_00615.jpeg from the source directory.
# Removed train_01787.jpeg from the source directory.
# Removed train_03854.jpeg from the source directory.
# Removed train_07476.jpeg from the source directory.
# Removed train_06201.jpeg from the source directory.
# Removed train_10167.jpeg from the source directory.
# Removed train_05699.jpeg from the source directory.
# Removed train_09639.jpeg from the source directory.
# Removed train_05492.jpeg from the source directory.
# Removed train_07847.jpeg from the source directory.
# Removed train_03080.jpeg from the source directory.
# Removed train_07388.jpeg from the source directory.
# Removed train_03165.jpeg from the source directory.
# Removed train_06607.jpeg from the source directory.
# Removed train_02429.jpeg from the source directory.
# Removed train_06370.jpeg from the source directory.
# Removed train_02149.jpeg from the source directory.
# Removed train_02945.jpeg from the source directory.
# Removed train_07110.jpeg from the source directory.
# Removed train_05099.jpeg from the source directory.
# Removed train_05503.jpeg from the source directory.
# Removed train_04906.jpeg from the source directory.
# Removed train_09845.jpeg from the source directory.
# Removed train_01996.jpeg from the source directory.
# Removed train_09951.jpeg from the source directory.
# Removed train_04319.jpeg from the source directory.
# Removed train_06890.jpeg from the source directory.
# Removed train_04174.jpeg from the source directory.
# Removed train_05312.jpeg from the source directory.
# Removed train_09885.jpeg from the source directory.
# Removed train_01795.jpeg from the source directory.
# Removed train_03702.jpeg from the source directory.
# Removed train_04777.jpeg from the source directory.
# Removed train_07799.jpeg from the source directory.
# Removed train_00233.jpeg from the source directory.
# Removed train_07212.jpeg from the source directory.
# Removed train_06854.jpeg from the source directory.
# Removed train_03465.jpeg from the source directory.
# Removed train_01932.jpeg from the source directory.
# Removed train_00039.jpeg from the source directory.
# Removed train_02941.jpeg from the source directory.
# Removed train_00332.jpeg from the source directory.
# Removed train_06871.jpeg from the source directory.
# Removed train_07321.jpeg from the source directory.
# Removed train_09110.jpeg from the source directory.
# Removed train_04321.jpeg from the source directory.
# Removed train_04413.jpeg from the source directory.
# Removed train_03262.jpeg from the source directory.
# Removed train_00522.jpeg from the source directory.
# Removed train_02422.jpeg from the source directory.
# Removed train_10106.jpeg from the source directory.
# Removed train_02314.jpeg from the source directory.
# Removed train_04501.jpeg from the source directory.
# Removed train_06371.jpeg from the source directory.
# Removed train_08206.jpeg from the source directory.
# Removed train_02882.jpeg from the source directory.
# Removed train_04975.jpeg from the source directory.
# Removed train_09968.jpeg from the source directory.
# Removed train_07223.jpeg from the source directory.
# Removed train_09644.jpeg from the source directory.
# Removed train_08406.jpeg from the source directory.
# Removed train_10325.jpeg from the source directory.
# Removed train_02479.jpeg from the source directory.
# Removed train_01515.jpeg from the source directory.
# Removed train_07324.jpeg from the source directory.
# Removed train_07086.jpeg from the source directory.
# Removed train_03329.jpeg from the source directory.
# Removed train_07171.jpeg from the source directory.
# Removed train_02286.jpeg from the source directory.
# Removed train_04484.jpeg from the source directory.
# Removed train_09957.jpeg from the source directory.
# Removed train_03969.jpeg from the source directory.
# Removed train_08136.jpeg from the source directory.
# Removed train_01726.jpeg from the source directory.
# Removed train_05666.jpeg from the source directory.
# Removed train_04012.jpeg from the source directory.
# Removed train_06788.jpeg from the source directory.
# Removed train_03774.jpeg from the source directory.
# Removed train_04544.jpeg from the source directory.
# Removed train_01120.jpeg from the source directory.
# Removed train_02239.jpeg from the source directory.
# Removed train_03627.jpeg from the source directory.
# Removed train_01209.jpeg from the source directory.
# Removed train_00956.jpeg from the source directory.
# Removed train_05261.jpeg from the source directory.
# Removed train_08071.jpeg from the source directory.
# Removed train_04037.jpeg from the source directory.
# Removed train_02471.jpeg from the source directory.
# Removed train_09131.jpeg from the source directory.
# Removed train_05136.jpeg from the source directory.
# Removed train_08481.jpeg from the source directory.
# Removed train_01941.jpeg from the source directory.
# Removed train_05300.jpeg from the source directory.
# Removed train_04460.jpeg from the source directory.
# Removed train_09711.jpeg from the source directory.
# Removed train_05265.jpeg from the source directory.
# Removed train_09474.jpeg from the source directory.
# Removed train_09672.jpeg from the source directory.
# Removed train_07563.jpeg from the source directory.
# Removed train_01710.jpeg from the source directory.
# Removed train_07791.jpeg from the source directory.
# Removed train_02748.jpeg from the source directory.
# Removed train_03430.jpeg from the source directory.
# Removed train_05490.jpeg from the source directory.
# Removed train_06265.jpeg from the source directory.
# Removed train_03783.jpeg from the source directory.
# Removed train_07251.jpeg from the source directory.
# Removed train_02857.jpeg from the source directory.
# Removed train_06899.jpeg from the source directory.
# Removed train_05279.jpeg from the source directory.
# Removed train_00339.jpeg from the source directory.
# Removed train_03210.jpeg from the source directory.
# Removed train_07483.jpeg from the source directory.
# Removed train_01352.jpeg from the source directory.
# Removed train_09425.jpeg from the source directory.
# Removed train_04965.jpeg from the source directory.
# Removed train_02660.jpeg from the source directory.
# Removed train_09052.jpeg from the source directory.
# Removed train_06149.jpeg from the source directory.
# Removed train_02762.jpeg from the source directory.
# Removed train_05632.jpeg from the source directory.
# Removed train_01564.jpeg from the source directory.
# Removed train_02349.jpeg from the source directory.
# Removed train_06463.jpeg from the source directory.
# Removed train_03348.jpeg from the source directory.
# Removed train_00975.jpeg from the source directory.
# Removed train_05649.jpeg from the source directory.
# Removed train_05723.jpeg from the source directory.
# Removed train_00681.jpeg from the source directory.
# Removed train_00469.jpeg from the source directory.
# Removed train_04541.jpeg from the source directory.
# Removed train_02649.jpeg from the source directory.
# Removed train_10196.jpeg from the source directory.
# Removed train_04217.jpeg from the source directory.
# Removed train_03201.jpeg from the source directory.
# Removed train_10188.jpeg from the source directory.
# Removed train_04055.jpeg from the source directory.
# Removed train_03187.jpeg from the source directory.
# Removed train_04290.jpeg from the source directory.
# Removed train_08340.jpeg from the source directory.
# Removed train_10354.jpeg from the source directory.
# Removed train_05721.jpeg from the source directory.
# Removed train_04332.jpeg from the source directory.
# Removed train_03325.jpeg from the source directory.
# Removed train_03789.jpeg from the source directory.
# Removed train_09095.jpeg from the source directory.
# Removed train_10234.jpeg from the source directory.
# Removed train_00399.jpeg from the source directory.
# Removed train_03971.jpeg from the source directory.
# Removed train_08515.jpeg from the source directory.
# Removed train_04833.jpeg from the source directory.
# Removed train_00569.jpeg from the source directory.
# Removed train_05070.jpeg from the source directory.
# Removed train_04119.jpeg from the source directory.
# Removed train_08525.jpeg from the source directory.
# Removed train_08371.jpeg from the source directory.
# Removed train_02122.jpeg from the source directory.
# Removed train_06561.jpeg from the source directory.
# Removed train_04760.jpeg from the source directory.
# Removed train_09636.jpeg from the source directory.
# Removed train_09603.jpeg from the source directory.
# Removed train_00409.jpeg from the source directory.
# Removed train_06294.jpeg from the source directory.
# Removed train_09553.jpeg from the source directory.
# Removed train_10350.jpeg from the source directory.
# Removed train_04466.jpeg from the source directory.
# Removed train_03791.jpeg from the source directory.
# Removed train_00365.jpeg from the source directory.
# Removed train_09377.jpeg from the source directory.
# Removed train_06319.jpeg from the source directory.
# Removed train_09634.jpeg from the source directory.
# Removed train_08404.jpeg from the source directory.
# Removed train_05995.jpeg from the source directory.
# Removed train_02494.jpeg from the source directory.
# Removed train_04076.jpeg from the source directory.
# Removed train_01435.jpeg from the source directory.
# Removed train_07330.jpeg from the source directory.
# Removed train_02947.jpeg from the source directory.
# Removed train_06836.jpeg from the source directory.
# Removed train_08992.jpeg from the source directory.
# Removed train_06532.jpeg from the source directory.
# Removed train_06509.jpeg from the source directory.
# Removed train_03312.jpeg from the source directory.
# Removed train_05922.jpeg from the source directory.
# Removed train_00725.jpeg from the source directory.
# Removed train_05055.jpeg from the source directory.
# Removed train_00758.jpeg from the source directory.
# Removed train_08986.jpeg from the source directory.
# Removed train_02798.jpeg from the source directory.
# Removed train_00113.jpeg from the source directory.
# Removed train_02144.jpeg from the source directory.
# Removed train_06502.jpeg from the source directory.
# Removed train_02944.jpeg from the source directory.
# Removed train_08174.jpeg from the source directory.
# Removed train_08851.jpeg from the source directory.
# Removed train_07478.jpeg from the source directory.
# Removed train_06233.jpeg from the source directory.
# Removed train_05156.jpeg from the source directory.
# Removed train_10145.jpeg from the source directory.
# Removed train_01641.jpeg from the source directory.
# Removed train_06901.jpeg from the source directory.
# Removed train_10092.jpeg from the source directory.
# Removed train_09517.jpeg from the source directory.
# Removed train_06414.jpeg from the source directory.
# Removed train_04523.jpeg from the source directory.
# Removed train_04868.jpeg from the source directory.
# Removed train_02410.jpeg from the source directory.
# Removed train_08681.jpeg from the source directory.
# Removed train_07003.jpeg from the source directory.
# Removed train_03745.jpeg from the source directory.
# Removed train_02550.jpeg from the source directory.
# Removed train_09557.jpeg from the source directory.
# Removed train_05570.jpeg from the source directory.
# Removed train_01871.jpeg from the source directory.
# Removed train_07580.jpeg from the source directory.
# Removed train_10051.jpeg from the source directory.
# Removed train_02008.jpeg from the source directory.
# Removed train_08705.jpeg from the source directory.
# Removed train_09554.jpeg from the source directory.
# Removed train_05011.jpeg from the source directory.
# Removed train_01778.jpeg from the source directory.
# Removed train_02443.jpeg from the source directory.
# Removed train_04517.jpeg from the source directory.
# Removed train_00101.jpeg from the source directory.
# Removed train_08675.jpeg from the source directory.
# Removed train_01108.jpeg from the source directory.
# Removed train_06215.jpeg from the source directory.
# Removed train_09534.jpeg from the source directory.
# Removed train_00085.jpeg from the source directory.
# Removed train_02975.jpeg from the source directory.
# Removed train_08293.jpeg from the source directory.
# Removed train_08719.jpeg from the source directory.
# Removed train_01117.jpeg from the source directory.
# Removed train_03167.jpeg from the source directory.
# Removed train_05542.jpeg from the source directory.
# Removed train_10288.jpeg from the source directory.
# Removed train_05227.jpeg from the source directory.
# Removed train_06676.jpeg from the source directory.
# Removed train_03558.jpeg from the source directory.
# Removed train_03301.jpeg from the source directory.
# Removed train_06525.jpeg from the source directory.
# Removed train_03034.jpeg from the source directory.
# Removed train_01997.jpeg from the source directory.
# Removed train_00942.jpeg from the source directory.
# Removed train_01256.jpeg from the source directory.
# Removed train_01550.jpeg from the source directory.
# Removed train_07325.jpeg from the source directory.
# Removed train_08732.jpeg from the source directory.
# Removed train_05963.jpeg from the source directory.
# Removed train_04773.jpeg from the source directory.
# Removed train_05724.jpeg from the source directory.
# Removed train_02600.jpeg from the source directory.
# Removed train_06731.jpeg from the source directory.
# Removed train_00918.jpeg from the source directory.
# Removed train_05560.jpeg from the source directory.
# Removed train_02480.jpeg from the source directory.
# Removed train_00704.jpeg from the source directory.
# Removed train_09427.jpeg from the source directory.
# Removed train_05727.jpeg from the source directory.
# Removed train_07863.jpeg from the source directory.
# Removed train_09755.jpeg from the source directory.
# Removed train_00274.jpeg from the source directory.
# Removed train_09983.jpeg from the source directory.
# Removed train_08673.jpeg from the source directory.
# Removed train_04885.jpeg from the source directory.
# Removed train_03630.jpeg from the source directory.
# Removed train_02529.jpeg from the source directory.
# Removed train_00040.jpeg from the source directory.
# Removed train_05425.jpeg from the source directory.
# Removed train_02730.jpeg from the source directory.
# Removed train_06925.jpeg from the source directory.
# Removed train_10260.jpeg from the source directory.
# Removed train_00427.jpeg from the source directory.

# %% [markdown]
# # Eda

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Specify the path to your "train" folder
train_folder = "/home/saidinesh/Desktop/Projects/yolov5/datasets/crop-datasets/classify-generated/train"

# Initialize variables to keep track of aspect ratio, width, and height
aspect_ratios = []
widths = []
heights = []

# Loop through the images in the folder, read each image, and calculate the aspect ratio, width, and height
for class_name in os.listdir(train_folder):
    class_path = os.path.join(train_folder, class_name)
    if os.path.isdir(class_path):
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            if image_path.endswith(('.jpg', '.jpeg', '.png', '.bmp')):
                image = cv2.imread(image_path)
                if image is not None:
                    h, w, _ = image.shape
                    aspect_ratio = w / h
                    aspect_ratios.append(aspect_ratio)
                    widths.append(w)
                    heights.append(h)

# Calculate the average aspect ratio, average width, and average height
avg_aspect_ratio = np.mean(aspect_ratios)
avg_width = np.mean(widths)
avg_height = np.mean(heights)

# Print the results
print(f"Average Aspect Ratio: {avg_aspect_ratio:.2f}")
print(f"Average Width: {avg_width:.2f} pixels")
print(f"Average Height: {avg_height:.2f} pixels")

# Plot histogram of aspect ratios
plt.hist(aspect_ratios, bins=50, range=(0, 5))
plt.title("Aspect Ratio Distribution")
plt.xlabel("Aspect Ratio")
plt.ylabel("Frequency")
plt.show()

# Plot histogram of widths
plt.hist(widths, bins=50, range=(0, 2000))
plt.title("Width Distribution")
plt.xlabel("Width (pixels)")
plt.ylabel("Frequency")
plt.show()

# Plot histogram of heights
plt.hist(heights, bins=50, range=(0, 2000))
plt.title("Height Distribution")
plt.xlabel("Height (pixels)")
plt.ylabel("Frequency")
plt.show()
# Out:
# Average Aspect Ratio: 1.01
# Average Width: 672.11 pixels
# Average Height: 686.75 pixels

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
import os
import random
import shutil

# Source directories
source_dirs = [
    '/home/saidinesh/Desktop/Projects/yolov5/datasets/crop-datasets/roboflow-sampling/train/albopictus',
    '/home/saidinesh/Desktop/Projects/yolov5/datasets/crop-datasets/roboflow-sampling/train/culex'
]

# Destination directory
destination_root_dir = '/home/saidinesh/Desktop/Projects/yolov5/datasets/crop-datasets/random_samples'

# Percentage of images to move (20%)
percentage_to_move = 20

# Create the destination directories if they don't exist
os.makedirs(destination_root_dir, exist_ok=True)

# Function to move a random percentage of files from source to destination
def move_random_files(source_dir, destination_dir, percentage):
    files = os.listdir(source_dir)
    num_files_to_move = int(len(files) * (percentage / 100))
    
    if num_files_to_move > 0:
        random_files = random.sample(files, num_files_to_move)
        for file in random_files:
            source_path = os.path.join(source_dir, file)
            destination_path = os.path.join(destination_dir, file)
            shutil.move(source_path, destination_path)
            print(f"Moved: {file}")

# Loop through source directories and move random files to separate folders
for source_dir in source_dirs:
    class_name = os.path.basename(source_dir)
    destination_dir = os.path.join(destination_root_dir, class_name)
    os.makedirs(destination_dir, exist_ok=True)
    move_random_files(source_dir, destination_dir, percentage_to_move)

print(f"Moved {percentage_to_move}% of images from source directories to separate class folders in {destination_root_dir}.")

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-136-g71244ae Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/166.8 GB disk)

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                          'path/*.jpg'  # glob
#                          'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                          'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-136-g71244ae Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 24.5MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 41.5ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 60.0ms
# Speed: 0.5ms pre-process, 50.8ms inference, 37.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip
# Out:
# 100%|██████████| 780M/780M [00:12<00:00, 66.6MB/s]

# %%
# Validate YOLOv5s on COCO val
# !python val.py --weights yolov5s.pt --data coco.yaml --img 640 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5s.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v7.0-136-g71244ae Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# val: Scanning /content/datasets/coco/val2017... 4952 images, 48 backgrounds, 0 corrupt: 100% 5000/5000 [00:02<00:00, 2024.59it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 157/157 [01:25<00:00,  1.84it/s]
#                    all       5000      36335      0.671      0.519      0.566      0.371
# Speed: 0.1ms pre-process, 3.1ms inference, 2.3ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5s_predictions.json...
# loading annotations into memory...
# Done (t=0.43s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.32s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=78.89s).
# Accumulating evaluation results...
# DONE (t=14.51s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.572
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.423
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.722
# Results saved to runs/val/exp

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://bit.ly/ultralytics_hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/im/integrations-loop.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br>
#
# A **Mosaic Dataloader** is used for training which combines 4 images into 1 mosaic.
#
# ## Label a dataset on Roboflow (optional)
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Comet Logging and Visualization 🌟 NEW
#
# [Comet](https://www.comet.com/site/lp/yolov5-with-comet/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab) is now fully integrated with YOLOv5. Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab)! Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# Getting started is easy:
# ```shell
# pip install comet_ml  # 1. install
# export COMET_API_KEY=<Your API Key>  # 2. paste API key
# python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt  # 3. train
# ```
# To learn more about all of the supported Comet features for this integration, check out the [Comet Tutorial](https://docs.ultralytics.com/yolov5/tutorials/comet_logging_integration). If you'd like to learn more about Comet, head over to our [documentation](https://www.comet.com/docs/v2/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab). Get started by trying out the Comet Colab Notebook:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1RG0WOQyxlDlo5Km8GogJpIEJlg_5lyYO?usp=sharing)
#
# <a href="https://bit.ly/yolov5-readme-comet2">
# <img alt="Comet Dashboard" src="https://user-images.githubusercontent.com/26833433/202851203-164e94e1-2238-46dd-91f8-de020e9d6b41.png" width="1280"/></a>

# %% [markdown]
# ## ClearML Logging and Automation 🌟 NEW
#
# [ClearML](https://cutt.ly/yolov5-notebook-clearml) is completely integrated into YOLOv5 to track your experimentation, manage dataset versions and even remotely execute training runs. To enable ClearML (check cells above):
#
# - `pip install clearml`
# - run `clearml-init` to connect to a ClearML server (**deploy your own [open-source server](https://github.com/allegroai/clearml-server)**, or use our [free hosted server](https://cutt.ly/yolov5-notebook-clearml))
#
# You'll get all the great expected features from an experiment manager: live updates, model upload, experiment comparison etc. but ClearML also tracks uncommitted changes and installed packages for example. Thanks to that ClearML Tasks (which is what we call experiments) are also reproducible on different machines! With only 1 extra line, we can schedule a YOLOv5 training task on a queue to be executed by any number of ClearML Agents (workers).
#
# You can use ClearML Data to version your dataset and then pass it to YOLOv5 simply using its unique ID. This will help you keep track of your data without adding extra hassle. Explore the [ClearML Tutorial](https://docs.ultralytics.com/yolov5/tutorials/clearml_logging_integration) for details!
#
# <a href="https://cutt.ly/yolov5-notebook-clearml">
# <img alt="ClearML Experiment Management UI" src="https://github.com/thepycoder/clearml_screenshots/raw/main/scalars.jpg" width="1280"/></a>

# %% [markdown]
# ## Local Logging
#
# Training results are automatically logged with [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) loggers to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc.
#
# This directory contains train and val statistics, mosaics, labels, predictions and augmentated mosaics, as well as metrics and charts including precision-recall (PR) curves and confusion matrices.
#
# <img alt="Local logging results" src="https://user-images.githubusercontent.com/26833433/183222430-e1abd1b7-782c-4cde-b04d-ad52926bf818.jpg" width="1280"/>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Notebooks** with free GPU: <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a> <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/google_cloud_quickstart_tutorial/)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/aws_quickstart_tutorial/)
# - **Docker Image**. See [Docker Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/docker_image_quickstart_tutorial/) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![YOLOv5 CI](https://github.com/ultralytics/yolov5/actions/workflows/ci-testing.yml/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# YOLOv5 PyTorch HUB Inference (DetectionModels only)
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', force_reload=True, trust_repo=True)  # or yolov5n - yolov5x6 or custom
im = 'https://ultralytics.com/images/zidane.jpg'  # file, Path, PIL.Image, OpenCV, nparray, list
results = model(im)  # inference
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
